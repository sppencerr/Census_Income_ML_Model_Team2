# %% [markdown]
# ## Exploratory Analysis of Census Income Data
# * Objective: Predict whether income exceeds $50K/yr based on census data, also known as Adult dataset
# * Data cleanup approach: TBD
# * Machine Learning Models: TBD
#
# ### Source of information:
# * https://archive.ics.uci.edu/dataset/20/census+income

# %% [markdown]
# ## Step 1 - Install and import the required libraries

# %%
# Import required dependencies
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import roc_auc_score, roc_curve, auc, confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import learning_curve

import matplotlib.pyplot as plt
import numpy as np
import warnings
from sklearn.metrics import balanced_accuracy_score
warnings.filterwarnings("ignore")

import seaborn as sns

# %% [markdown]
# -------------------------

# %% [markdown]
# ## Step 2 - Data Preparation
# * Upload all the source files into /resources folder and add column headers:
#   * adult.data - which is used as the train data
#   * adult.test - which is used as the test data
# * Check the tables to understand data types, missing values, and fix them for better data quality

# %%
# Import the data
census_df = pd.read_csv('./resources/adult.data')
census_test_df = pd.read_csv('./resources/adult.test', skiprows=1) # skip the first row as it might contain headers

# %%
# Display the first 10 rows of the data
display(census_df.head(10))
display(census_test_df.head(10))
# Out:
#    39          State-gov   77516      Bachelors   13           Never-married  \
# 0  50   Self-emp-not-inc   83311      Bachelors   13      Married-civ-spouse
# 1  38            Private  215646        HS-grad    9                Divorced
# 2  53            Private  234721           11th    7      Married-civ-spouse
# 3  28            Private  338409      Bachelors   13      Married-civ-spouse
# 4  37            Private  284582        Masters   14      Married-civ-spouse
# 5  49            Private  160187            9th    5   Married-spouse-absent
# 6  52   Self-emp-not-inc  209642        HS-grad    9      Married-civ-spouse
# 7  31            Private   45781        Masters   14           Never-married
# 8  42            Private  159449      Bachelors   13      Married-civ-spouse
# 9  37            Private  280464   Some-college   10      Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# ...

# %% [markdown]
# #### This section is for the census_df train datasets

# %%
# Add labels to the columns of the census_df
census_df.columns = [
    'age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income'
]

census_df.head(10)
# Out:
#    age          workclass  fnlwgt      education  education-num  \
# 0   50   Self-emp-not-inc   83311      Bachelors             13
# 1   38            Private  215646        HS-grad              9
# 2   53            Private  234721           11th              7
# 3   28            Private  338409      Bachelors             13
# 4   37            Private  284582        Masters             14
# 5   49            Private  160187            9th              5
# 6   52   Self-emp-not-inc  209642        HS-grad              9
# 7   31            Private   45781        Masters             14
# 8   42            Private  159449      Bachelors             13
# 9   37            Private  280464   Some-college             10
#
#            marital-status          occupation    relationship    race  \
# 0      Married-civ-spouse     Exec-managerial         Husband   White
# 1                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %%
# Check how many rows of census_df
census_df.shape
# Out:
# (32560, 15)

# %%
# Describe census_df
census_df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
# Check for missing values
census_df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
# Check unique values in the each column
for column in census_df.columns:
    print(column)
    print(census_df[column].unique())
    print()
# Out:
# age
# [50 38 53 28 37 49 52 31 42 30 23 32 40 34 25 43 54 35 59 56 19 39 20 45
#  22 48 21 24 57 44 41 29 18 47 46 36 79 27 67 33 76 17 55 61 70 64 71 68
#  66 51 58 26 60 90 75 65 77 62 63 80 72 74 69 73 81 78 88 82 83 84 85 86
#  87]
#
# workclass
# [' Self-emp-not-inc' ' Private' ' State-gov' ' Federal-gov' ' Local-gov'
#  ' ?' ' Self-emp-inc' ' Without-pay' ' Never-worked']
#
# fnlwgt
# [ 83311 215646 234721 ...  34066  84661 257302]
#
# education
# [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']
#
# education-num
# [13  9  7 14  5 10 12 11  4 16 15  3  6  2  1  8]
#
# marital-status
# [' Married-civ-spouse' ' Divorced' ' Married-spouse-absent'
#  ' Never-married' ' Separated' ' Married-AF-spouse' ' Widowed']
#
# occupation
# [' Exec-managerial' ' Handlers-cleaners' ' Prof-specialty'
# ...

# %%
# The workclass, occupation, and native-country columns have a value '?' which means it is a missing value. 
# We will replace these values with a plain 'Unknown' value
# Note some of these ? have extra spaces around them

census_df['workclass'] = census_df['workclass'].replace(r'^\s*\?\s*$', 'Unknown', regex=True)
census_df['occupation'] = census_df['occupation'].replace(r'^\s*\?\s*$', 'Unknown', regex=True)
census_df['native-country'] = census_df['native-country'].replace(r'^\s*\?\s*$', 'Unknown', regex=True)


# From all records, remove any extra spaces around any values
census_df = census_df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# From all records, remove dot character around any values
census_df = census_df.apply(lambda x: x.str.replace('.', '') if x.dtype == "object" else x)

# %%
# Check how many rows of census_df
census_df.shape
# Out:
# (32560, 15)

# %%
# Check unique values in the each column
# Make sure there are no "?", ".", or extra spaces in the values
for column in census_df.columns:
    print(column)
    print(census_df[column].unique())
    print()
# Out:
# age
# [50 38 53 28 37 49 52 31 42 30 23 32 40 34 25 43 54 35 59 56 19 39 20 45
#  22 48 21 24 57 44 41 29 18 47 46 36 79 27 67 33 76 17 55 61 70 64 71 68
#  66 51 58 26 60 90 75 65 77 62 63 80 72 74 69 73 81 78 88 82 83 84 85 86
#  87]
#
# workclass
# ['Self-emp-not-inc' 'Private' 'State-gov' 'Federal-gov' 'Local-gov'
#  'Unknown' 'Self-emp-inc' 'Without-pay' 'Never-worked']
#
# fnlwgt
# [ 83311 215646 234721 ...  34066  84661 257302]
#
# education
# ['Bachelors' 'HS-grad' '11th' 'Masters' '9th' 'Some-college' 'Assoc-acdm'
#  'Assoc-voc' '7th-8th' 'Doctorate' 'Prof-school' '5th-6th' '10th'
#  '1st-4th' 'Preschool' '12th']
#
# education-num
# [13  9  7 14  5 10 12 11  4 16 15  3  6  2  1  8]
#
# marital-status
# ['Married-civ-spouse' 'Divorced' 'Married-spouse-absent' 'Never-married'
#  'Separated' 'Married-AF-spouse' 'Widowed']
#
# occupation
# ['Exec-managerial' 'Handlers-cleaners' 'Prof-specialty' 'Other-service'
#  'Adm-clerical' 'Sales' 'Craft-repair' 'Transport-moving'
# ...

# %% [markdown]
# ##### For the Train datasets, we cleaned up all cells with "?" sign, "." sign, and any extra spaces surrounding the values
# ##### Records with "?" sign are replaced with a plain "Unknown" text
# ##### We kept the same 32,560 rows

# %% [markdown]
# -------------------------

# %% [markdown]
# #### This section is for the census_test_df test datasets

# %%
# Add labels to the columns of the census_test_df
census_test_df.columns = [
    'age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income'
]

census_test_df.head(10)
# Out:
#    age          workclass  fnlwgt      education  education-num  \
# 0   38            Private   89814        HS-grad              9
# 1   28          Local-gov  336951     Assoc-acdm             12
# 2   44            Private  160323   Some-college             10
# 3   18                  ?  103497   Some-college             10
# 4   34            Private  198693           10th              6
# 5   29                  ?  227026        HS-grad              9
# 6   63   Self-emp-not-inc  104626    Prof-school             15
# 7   24            Private  369667   Some-college             10
# 8   55            Private  104996        7th-8th              4
# 9   65            Private  184454        HS-grad              9
#
#         marital-status          occupation    relationship    race      sex  \
# 0   Married-civ-spouse     Farming-fishing         Husband   White     Male
# 1   Married-civ-spouse     Protective-serv         Husband   White     Male
# ...

# %%
# Check how many rows of census_test_df
census_test_df.shape
# Out:
# (16280, 15)

# %%
# Describe census_test_df
census_test_df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  16280.000000  1.628000e+04   16280.000000   16280.00000  16280.000000
# mean      38.768305  1.894334e+05      10.073096    1081.97156     87.904668
# std       13.849192  1.057177e+05       2.567511    7584.16416    403.117078
# min       17.000000  1.349200e+04       1.000000       0.00000      0.000000
# 25%       28.000000  1.167162e+05       9.000000       0.00000      0.000000
# 50%       37.000000  1.778295e+05      10.000000       0.00000      0.000000
# 75%       48.000000  2.383840e+05      12.000000       0.00000      0.000000
# max       90.000000  1.490400e+06      16.000000   99999.00000   3770.000000
#
#        hours-per-week
# count    16280.000000
# mean        40.392260
# std         12.479715
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
# Check for missing values
census_test_df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
# Check unique values in the each column
for column in census_test_df.columns:
    print(column)
    print(census_test_df[column].unique())
    print()
# Out:
# age
# [38 28 44 18 34 29 63 24 55 65 36 26 58 48 43 20 37 40 72 25 45 22 23 54
#  32 46 56 17 39 52 21 42 33 30 47 41 19 69 50 31 59 49 51 27 57 61 64 79
#  73 53 77 80 62 35 68 66 75 60 67 71 70 90 81 74 78 82 83 85 76 84 89 88
#  87]
#
# workclass
# [' Private' ' Local-gov' ' ?' ' Self-emp-not-inc' ' Federal-gov'
#  ' State-gov' ' Self-emp-inc' ' Without-pay' ' Never-worked']
#
# fnlwgt
# [ 89814 336951 160323 ... 349230 321403  83891]
#
# education
# [' HS-grad' ' Assoc-acdm' ' Some-college' ' 10th' ' Prof-school'
#  ' 7th-8th' ' Bachelors' ' Masters' ' Doctorate' ' 11th' ' 5th-6th'
#  ' Assoc-voc' ' 9th' ' 12th' ' 1st-4th' ' Preschool']
#
# education-num
# [ 9 12 10  6 15  4 13 14 16  7  3 11  5  8  2  1]
#
# marital-status
# [' Married-civ-spouse' ' Never-married' ' Widowed' ' Divorced'
#  ' Separated' ' Married-spouse-absent' ' Married-AF-spouse']
#
# occupation
# [' Farming-fishing' ' Protective-serv' ' Machine-op-inspct' ' ?'
# ...

# %%
# The workclass, occupation, and native-country columns have a value '?' which means it is a missing value. 
# We will replace it with a NaN value
census_test_df['workclass'] = census_df['workclass'].replace(r'^\s*\?\s*$', 'Unknown', regex=True)
census_test_df['occupation'] = census_df['occupation'].replace(r'^\s*\?\s*$', 'Unknown', regex=True)
census_test_df['native-country'] = census_df['native-country'].replace(r'^\s*\?\s*$', 'Unknown', regex=True)

# From all records, remove any extra spaces around any values
census_test_df = census_test_df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# From all records, remove dot character around any values
census_test_df = census_test_df.apply(lambda x: x.str.replace('.', '') if x.dtype == "object" else x)

# %%
# Check how many rows of census_test_df
census_test_df.shape
# Out:
# (16280, 15)

# %%
# Check unique values in the each column
# Make sure there are no "?", ".", or extra spaces in the values
for column in census_test_df.columns:
    print(column)
    print(census_test_df[column].unique())
    print()
# Out:
# age
# [38 28 44 18 34 29 63 24 55 65 36 26 58 48 43 20 37 40 72 25 45 22 23 54
#  32 46 56 17 39 52 21 42 33 30 47 41 19 69 50 31 59 49 51 27 57 61 64 79
#  73 53 77 80 62 35 68 66 75 60 67 71 70 90 81 74 78 82 83 85 76 84 89 88
#  87]
#
# workclass
# ['Self-emp-not-inc' 'Private' 'State-gov' 'Federal-gov' 'Local-gov'
#  'Unknown' 'Self-emp-inc' 'Without-pay' 'Never-worked']
#
# fnlwgt
# [ 89814 336951 160323 ... 349230 321403  83891]
#
# education
# ['HS-grad' 'Assoc-acdm' 'Some-college' '10th' 'Prof-school' '7th-8th'
#  'Bachelors' 'Masters' 'Doctorate' '11th' '5th-6th' 'Assoc-voc' '9th'
#  '12th' '1st-4th' 'Preschool']
#
# education-num
# [ 9 12 10  6 15  4 13 14 16  7  3 11  5  8  2  1]
#
# marital-status
# ['Married-civ-spouse' 'Never-married' 'Widowed' 'Divorced' 'Separated'
#  'Married-spouse-absent' 'Married-AF-spouse']
#
# occupation
# ['Exec-managerial' 'Handlers-cleaners' 'Prof-specialty' 'Other-service'
#  'Adm-clerical' 'Sales' 'Craft-repair' 'Transport-moving'
# ...

# %% [markdown]
# ##### For the Test datasets, we cleaned up all cells with "?" sign, "." sign, and any extra spaces surrounding the values
# ##### Records with "?" sign are replaced with a plain "Unknown" text
# ##### We kept the same 16,280 rows

# %% [markdown]
# -------------------------

# %% [markdown]
# ## Step 3 - Create a visualization for the data

# %%
# Create a visualization of the education column for each census_df and census_test_df

plt.clf()
plt.figure(figsize=(10, 3))
train_work_counts = census_df['education'].value_counts()
test_work_counts = census_test_df['education'].value_counts()

plt.plot(train_work_counts.index, train_work_counts.values, marker='o', color='blue')
plt.plot(test_work_counts.index, test_work_counts.values, marker='o', color='red')
plt.xticks(rotation=45)
plt.title('Education Level Count')
plt.legend(['Census Data', 'Census Test Data'])
plt.grid(True)
plt.show()

# %%
# Create a visualization of the marital status column for each census_df and census_test_df

plt.clf()
plt.figure(figsize=(10, 3))
train_work_counts = census_df['marital-status'].value_counts()
test_work_counts = census_test_df['marital-status'].value_counts()

plt.plot(train_work_counts.index, train_work_counts.values, marker='o', color='blue')
plt.plot(test_work_counts.index, test_work_counts.values, marker='o', color='red')
plt.xticks(rotation=45)
plt.title('Marital Status Level Count')
plt.legend(['Census Data', 'Census Test Data'])
plt.grid(True)
plt.show()

# %%
# Create a visualization of the workclass column for each census_df and census_test_df

plt.clf()
plt.figure(figsize=(10, 3))
train_work_counts = census_df['workclass'].value_counts()
test_work_counts = census_test_df['workclass'].value_counts()

plt.plot(train_work_counts.index, train_work_counts.values, marker='o', color='blue')
plt.plot(test_work_counts.index, test_work_counts.values, marker='o', color='red')
plt.xticks(rotation=45)
plt.title('Workclass Level Count')
plt.legend(['Census Data', 'Census Test Data'])
plt.grid(True)
plt.show()

# %%
# Create a visualization of the occupation column for each census_df and census_test_df

plt.clf()
plt.figure(figsize=(10, 3))
train_work_counts = census_df['occupation'].value_counts()
test_work_counts = census_test_df['occupation'].value_counts()

plt.plot(train_work_counts.index, train_work_counts.values, marker='o', color='blue')
plt.plot(test_work_counts.index, test_work_counts.values, marker='o', color='red')
plt.xticks(rotation=45)
plt.title('Occupation Level Count')
plt.legend(['Census Data', 'Census Test Data'])
plt.grid(True)
plt.show()

# %%
# Create a visualization of the relationship column for each census_df and census_test_df

plt.clf()
plt.figure(figsize=(10, 3))
train_work_counts = census_df['relationship'].value_counts()
test_work_counts = census_test_df['relationship'].value_counts()

plt.plot(train_work_counts.index, train_work_counts.values, marker='o', color='blue')
plt.plot(test_work_counts.index, test_work_counts.values, marker='o', color='red')
plt.xticks(rotation=45)
plt.title('Relationship Level Count')
plt.legend(['Census Data', 'Census Test Data'])
plt.grid(True)
plt.show()

# %%
# Create a visualization of the race column for each census_df and census_test_df

plt.clf()
plt.figure(figsize=(10, 3))
train_work_counts = census_df['race'].value_counts()
test_work_counts = census_test_df['race'].value_counts()

plt.plot(train_work_counts.index, train_work_counts.values, marker='o', color='blue')
plt.plot(test_work_counts.index, test_work_counts.values, marker='o', color='red')
plt.xticks(rotation=45)
plt.title('Race Level Count')
plt.legend(['Census Data', 'Census Test Data'])
plt.grid(True)
plt.show()

# %%
# Create a visualization of the sex column for each census_df and census_test_df

plt.clf()
plt.figure(figsize=(10, 3))
train_work_counts = census_df['sex'].value_counts()
test_work_counts = census_test_df['sex'].value_counts()

index = np.arange(len(train_work_counts.index))
width = 0.35

plt.bar(index - width/2, train_work_counts.values, width, label='Census Data', color='blue')
plt.bar(index + width/2, test_work_counts.values, width, label='Census Test Data', color='red')

plt.xticks(index, train_work_counts.index, rotation=45)
plt.title('Gender Level Count')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Create a visualization of the native country column for each census_df and census_test_df

plt.clf()
plt.figure(figsize=(30, 10))
train_work_counts = census_df['native-country'].value_counts()
test_work_counts = census_test_df['native-country'].value_counts()

plt.plot(train_work_counts.index, train_work_counts.values, marker='o', color='blue')
plt.plot(test_work_counts.index, test_work_counts.values, marker='o', color='red')
plt.xticks(rotation=45)
plt.title('Native Country Level Count')
plt.legend(['Census Data', 'Census Test Data'])
plt.grid(True)
plt.show()

# %%
# Create a visualization of the income column for each census_df and census_test_df

plt.clf()
plt.figure(figsize=(10, 3))
train_work_counts = census_df['income'].value_counts()
test_work_counts = census_test_df['income'].value_counts()

index = np.arange(len(train_work_counts.index))
width = 0.35

plt.bar(index - width/2, train_work_counts.values, width, label='Census Data', color='blue')
plt.bar(index + width/2, test_work_counts.values, width, label='Census Test Data', color='red')

plt.xticks(index, train_work_counts.index, rotation=45)
plt.title('Income Level Count')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# -------------------------

# %% [markdown]
# ## Step 4 - Binary Classification
# ### Transform datasets from object for the following columns into Binary / Numeric values:
#    * workclass
#    * education
#    * marital-status
#    * occupation
#    * relationship
#    * race
#    * sex
#    * native-country
#    * income

# %%
# Check original data type from census_df
census_df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# income            object
# dtype: object

# %%
# Check original data type from census_test_df
census_test_df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# income            object
# dtype: object

# %% [markdown]
# -------------------------

# %% [markdown]
# #### This section is for the census_df train datasets

# %% [markdown]
# -------------------------

# %% [markdown]
# #### This section is for the census_test_df test datasets
